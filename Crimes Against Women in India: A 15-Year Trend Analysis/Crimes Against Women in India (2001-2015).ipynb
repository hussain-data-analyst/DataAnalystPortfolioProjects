# %% [markdown]
# # Crimes Against Women in India: A 15-Year Trend Analysis (2001-2015)
#
# ## Project Overview
#
# This project analyzes crime data from 2001 to 2015, focusing on crimes against women across different states and districts in India. The aim is to uncover trends and patterns in various types of crimes, such as **Rape**, **Kidnapping and Abduction**, **Dowry Deaths**, and more. Insights were drawn using Python for data analysis and visualization, and Tableau was used for interactive dashboards.
#
# ### Objectives
# * Conduct year-wise analysis to observe trends and patterns in crimes against women over the years 2001-2015.
# * Perform state-wise and district-wise analysis to identify regions with the highest crime rates.
# * Investigate the most prevalent crimes within states and compare crime trends across regions.
# * Provide clear and impactful visualizations for better understanding and decision-making.
#
# ---
#
# ## Dataset
#
# The dataset was sourced from [data.gov.in](https://data.gov.in) and contains crime data related to women for the years 2001-2015. The dataset includes the following features:
#
# * **STATE/UT**: The State or Union Territory.
# * **DISTRICT**: Districts within each state.
# * **Year**: The year of recorded crimes.
# * **Crimes**: Various categories of crimes, including:
#   * Rape
#   * Kidnapping and Abduction
#   * Dowry Deaths
#   * Assault on women with intent to outrage modesty
#   * Insult to modesty of women
#   * Cruelty by Husband or his Relatives
#   * Importation of Girls
#   * Total Crimes
#
# ---
#
# ## Tools & Libraries Used
#
#   * **Python** for data analysis and cleaning.
#   * **Pandas**: Data manipulation.
#   * **NumPy**: Handling numerical operations.
#   * **Matplotlib** and **Seaborn**: Data visualization.
# * **Jupyter Notebook**: Used for coding and documenting the project.
#
# ---
#
# ## Project Workflow
#
# ### Part - 1 Data Loading & Preprocessing
# #### (i) **Data Cleaning**
# * Imported year-wise datasets, handled null values, removed redundant information, and standardized column names.
# * Merged all datasets into a clean, comprehensive file for analysis.
#
# ### Part - 2 Data Analysis and Visualization
# #### (i) **Data Exploration & Analysis**
# * **Year-wise Analysis**: Trends and patterns across various crimes over the years.
# * **State-wise Analysis**: Identified top 10 states with the highest and lowest crime rates.
# * **District-wise Analysis**: Found the top 5 districts with the highest number of crimes.
#
# #### (ii) **Visualizations**
# * Created bar charts, line charts, and heatmaps to visualize:
#   * Yearly trends for different types of crimes.
#   * State-wise and district-wise distribution of crimes.

# %% [markdown]
# # Part - 1 Data Loading & Preprocessing

# %% [markdown]
# ## 1. Importing Required Libraries

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 2. Loading Datasets from 2001 to 2015
#
# **Here, we are going to import four seperate datasets :**
# 1. Dataset from 2001 to 2012
# 2. Dataset 2013
# 3. Dataset 2014
# 4. Dataset 2015

# %%
# LOADING 2001 TO 2012 CRIMES DATA SET
df2001_2012 = pd.read_csv('dstrCAW_1.csv')
df2001_2012.sample(5)
# Out:
#              STATE/UT         DISTRICT  Year  Rape  Kidnapping and Abduction  \
# 3427        RAJASTHAN          KARAULI  2005    22                        41
# 7495            ASSAM         TINSUKIA  2011    61                       135
# 921   JAMMU & KASHMIR         ANANTNAG  2002    16                        58
# 5390        KARNATAKA  DAKSHIN KANNADA  2008    10                         6
# 133      CHHATTISGARH      RAJNANDGAON  2001    58                         3
#
#       Dowry Deaths  Assault on women with intent to outrage her modesty  \
# 3427            14                                                 40
# 7495             1                                                 27
# 921              0                                                 67
# 5390             5                                                 53
# 133              3                                                 92
#
#       Insult to modesty of Women  Cruelty by Husband or his Relatives  \
# ...

# %%
# LOADING 2013 CRIMES DATASET
df2013 = pd.read_csv('dstrCAW_2013.csv')
df2013.sample(5)
# Out:
#              STATE/UT       DISTRICT  Year  Rape  Kidnapping and Abduction  \
# 225  Himachal Pradesh       BILASPUR  2013    13                        43
# 191           Gujarat  SURENDRANAGAR  2013    18                        66
# 609         Rajasthan           TONK  2013    33                        76
# 659           Tripura            GRP  2013     0                         0
# 326         Karnataka       RAILWAYS  2013     1                         0
#
#      Dowry Deaths  Assault on women with intent to outrage her modesty  \
# 225             0                                                 32
# 191             0                                                 51
# 609             5                                                 75
# 659             0                                                  0
# 326             2                                                  3
#
#      Insult to modesty of Women  Cruelty by Husband or his Relatives  \
# ...

# %%
# LOADING 2014 CRIMES DATASET
df2014 = pd.read_csv('District-wise_Crimes_committed_against_Women_2014.csv')

# %%
df2014.sample(5)
# Out:
#           State/ UT  Sl. No.          District/ Area  Year  Rape  \
# 765     Uttarakhand       10            Rudra Prayag  2014     4
# 802   A & N Islands        2  North & Middle Andaman  2014    11
# 440     Maharashtra       36               Ratnagiri  2014    34
# 11   Andhra Pradesh       12             Rajahmundry  2014    35
# 324       Karnataka       35                 Yadgiri  2014    41
#
#      Attempt to commit Rape  Kidnapping & Abduction_Total  Dowry Deaths  \
# 765                       0                             7             1
# 802                       0                             8             0
# 440                       1                             8             0
# 11                        3                             8             3
# 324                       1                            21             2
#
#      Assault on Women with intent to outrage her Modesty_Total  \
# 765                                                  9
# ...

# %%
# LOADING THE DATESET FOR 2015 CRIMES
df2015 = pd.read_csv('District-wise_Crimes_committed_against_Women_2015_1.csv')

# %%
df2015.sample(5)
# Out:
#           State/ UT Sl. No.   District/ Area    Year  Rape  \
# 717   Uttar Pradesh      24           Etawah  2015.0  26.0
# 798     West Bengal      14  Howrah G. R. P.  2015.0   3.0
# 843        Delhi UT      17           SPUWAC  2015.0   0.0
# 781     Uttarakhand      11    Tehri Garhwal  2015.0   8.0
# 387  Madhya Pradesh      27           Jhabua  2015.0  31.0
#
#      Attempt to commit Rape  Kidnapping & Abduction_Total  Dowry Deaths  \
# 717                     5.0                         125.0          43.0
# 798                     0.0                           4.0           0.0
# 843                     0.0                           0.0           0.0
# 781                     0.0                          16.0           3.0
# 387                     0.0                         112.0           0.0
#
#      Assault on Women with intent to outrage her Modesty_Total  \
# 717                                              101.0
# ...

# %% [markdown]
# ## 3. Data Preprocessing and Cleaning

# %% [markdown]
# **The common features in all Four datasets are following :**
# - State/ UT
# - District/ Area
# - Year
# - Rape
# - Kidnapping & Abduction_Total
# - Dowry Deaths
# - Assault on Women with intent to outrage her Modesty_Total
# - Insult to the Modesty of Women_Total
# - Cruelty by Husband or his Relatives
# - Importation of Girls from Foreign Country
#
# **so, We will take only there feature from each column and delete all other features**

# %%
df2014_clean = df2014[['State/ UT', 'District/ Area', 'Year', 'Rape', 'Kidnapping & Abduction_Total',
       'Dowry Deaths',
       'Assault on Women with intent to outrage her Modesty_Total',
       'Insult to the Modesty of Women_Total',
       'Cruelty by Husband or his Relatives',
       'Importation of Girls from Foreign Country']]

# %%
# SELECTING ONLY THE FEATUR WE ARE INTERESTED IN 
df2015_clean = df2015[['State/ UT', 'District/ Area', 'Year', 'Rape', 'Kidnapping & Abduction_Total',
       'Dowry Deaths',
       'Assault on Women with intent to outrage her Modesty_Total',
       'Insult to the Modesty of Women_Total',
       'Cruelty by Husband or his Relatives',
       'Importation of Girls from Foreign Country']]

# %% [markdown]
# ### Looking for Feature Names

# %%
def col(x):
    return(pd.Series(x.columns))

# %%
col(df2001_2012)
# Out:
# 0                                             STATE/UT
# 1                                             DISTRICT
# 2                                                 Year
# 3                                                 Rape
# 4                             Kidnapping and Abduction
# 5                                         Dowry Deaths
# 6    Assault on women with intent to outrage her mo...
# 7                           Insult to modesty of Women
# 8                  Cruelty by Husband or his Relatives
# 9                                 Importation of Girls
# dtype: object

# %%
col(df2013)
# Out:
# 0                                             STATE/UT
# 1                                             DISTRICT
# 2                                                 Year
# 3                                                 Rape
# 4                             Kidnapping and Abduction
# 5                                         Dowry Deaths
# 6    Assault on women with intent to outrage her mo...
# 7                           Insult to modesty of Women
# 8                  Cruelty by Husband or his Relatives
# 9                                 Importation of Girls
# dtype: object

# %%
col(df2014_clean)
# Out:
# 0                                            State/ UT
# 1                                       District/ Area
# 2                                                 Year
# 3                                                 Rape
# 4                         Kidnapping & Abduction_Total
# 5                                         Dowry Deaths
# 6    Assault on Women with intent to outrage her Mo...
# 7                 Insult to the Modesty of Women_Total
# 8                  Cruelty by Husband or his Relatives
# 9            Importation of Girls from Foreign Country
# dtype: object

# %%
col(df2015_clean)
# Out:
# 0                                            State/ UT
# 1                                       District/ Area
# 2                                                 Year
# 3                                                 Rape
# 4                         Kidnapping & Abduction_Total
# 5                                         Dowry Deaths
# 6    Assault on Women with intent to outrage her Mo...
# 7                 Insult to the Modesty of Women_Total
# 8                  Cruelty by Husband or his Relatives
# 9            Importation of Girls from Foreign Country
# dtype: object

# %% [markdown]
# ## Assigning Same Column Names

# %% [markdown]
# **Spelling of each feature name is different in different dataset.
# so, we are going to assign them Uniform Names**
# - it will help us to concatinate these datasets

# %%
df2001_2012.columns = ['State/Ut', 'District', 'Year', 'Rape', 'Kidnapping & Abduction',
       'Dowry Deaths', 'Assault on women with intent to outrage her modesty',
       'Insult to modesty of Women', 'Cruelty by Husband or his Relatives',
       'Importation of Girls']

# %%
df2013.columns = ['State/Ut', 'District', 'Year', 'Rape', 'Kidnapping & Abduction',
       'Dowry Deaths', 'Assault on women with intent to outrage her modesty',
       'Insult to modesty of Women', 'Cruelty by Husband or his Relatives',
       'Importation of Girls']

# %%
df2014_clean.columns = ['State/Ut', 'District', 'Year', 'Rape', 'Kidnapping & Abduction',
       'Dowry Deaths', 'Assault on women with intent to outrage her modesty',
       'Insult to modesty of Women', 'Cruelty by Husband or his Relatives',
       'Importation of Girls']

# %%
df2015_clean.columns = ['State/Ut', 'District', 'Year', 'Rape', 'Kidnapping & Abduction',
       'Dowry Deaths', 'Assault on women with intent to outrage her modesty',
       'Insult to modesty of Women', 'Cruelty by Husband or his Relatives',
       'Importation of Girls']

# %% [markdown]
# ### Dealing with null valuse

# %%
def null(x) :
    return x.isnull().sum()

# %%
null(df2001_2012)
# Out:
# State/Ut                                               0
# District                                               0
# Year                                                   0
# Rape                                                   0
# Kidnapping & Abduction                                 0
# Dowry Deaths                                           0
# Assault on women with intent to outrage her modesty    0
# Insult to modesty of Women                             0
# Cruelty by Husband or his Relatives                    0
# Importation of Girls                                   0
# dtype: int64

# %%
null(df2013)
# Out:
# State/Ut                                               0
# District                                               0
# Year                                                   0
# Rape                                                   0
# Kidnapping & Abduction                                 0
# Dowry Deaths                                           0
# Assault on women with intent to outrage her modesty    0
# Insult to modesty of Women                             0
# Cruelty by Husband or his Relatives                    0
# Importation of Girls                                   0
# dtype: int64

# %%
null(df2014_clean)
# Out:
# State/Ut                                               0
# District                                               0
# Year                                                   0
# Rape                                                   0
# Kidnapping & Abduction                                 0
# Dowry Deaths                                           0
# Assault on women with intent to outrage her modesty    0
# Insult to modesty of Women                             0
# Cruelty by Husband or his Relatives                    0
# Importation of Girls                                   0
# dtype: int64

# %%
null(df2015_clean)
# Out:
# State/Ut                                               0
# District                                               1
# Year                                                   1
# Rape                                                   1
# Kidnapping & Abduction                                 1
# Dowry Deaths                                           1
# Assault on women with intent to outrage her modesty    1
# Insult to modesty of Women                             1
# Cruelty by Husband or his Relatives                    1
# Importation of Girls                                   1
# dtype: int64

# %% [markdown]
# There is one Null Value in each row of the Dataset 2015

# %%
df2015_clean[df2015_clean.isnull().sum(axis = 1)>=1]
# Out:
#        State/Ut District  Year  Rape  Kidnapping & Abduction  Dowry Deaths  \
# 852  Puducherry      NaN   NaN   NaN                     NaN           NaN
#
#      Assault on women with intent to outrage her modesty  \
# 852                                                NaN
#
#      Insult to modesty of Women  Cruelty by Husband or his Relatives  \
# 852                         NaN                                  NaN
#
#      Importation of Girls
# 852                   NaN

# %% [markdown]
# **Here , We can see 852 row have null values for all the features except 'State/Ut'
#  so will drop the 852 Row .**

# %%
df2015_clean = df2015_clean.drop(852,axis = 0)

# %%
df2015_clean.isnull().sum()
# Out:
# State/Ut                                               0
# District                                               0
# Year                                                   0
# Rape                                                   0
# Kidnapping & Abduction                                 0
# Dowry Deaths                                           0
# Assault on women with intent to outrage her modesty    0
# Insult to modesty of Women                             0
# Cruelty by Husband or his Relatives                    0
# Importation of Girls                                   0
# dtype: int64

# %% [markdown]
# Now,our Datasets have no any Null value .

# %% [markdown]
# #### REMOVE THE ROWS FROM DATASETS WHICH ARE SHOWING 'TOTAL NUMBER OF CRIMES IN THE STATE' OR 'TOTAL OF ALL DISTRICS'
# - Which is introducing Data Redundacy in our Dataset.Because all the crimes in each district are already mentioned and we can calculate Total crimes in each state by summing the crimes in each district and we don't need rows which are showing total crimes in each state.
# - Best way to eliminate this problem is by droping the Rows which are showing total of all Districts in a State.

# %%
df2001_2012
# Out:
#             State/Ut       District  Year  Rape  Kidnapping & Abduction  \
# 0     ANDHRA PRADESH       ADILABAD  2001    50                      30
# 1     ANDHRA PRADESH      ANANTAPUR  2001    23                      30
# 2     ANDHRA PRADESH       CHITTOOR  2001    27                      34
# 3     ANDHRA PRADESH       CUDDAPAH  2001    20                      20
# 4     ANDHRA PRADESH  EAST GODAVARI  2001    23                      26
# ...              ...            ...   ...   ...                     ...
# 9012     LAKSHADWEEP    LAKSHADWEEP  2012     0                       0
# 9013     LAKSHADWEEP          TOTAL  2012     0                       0
# 9014      PUDUCHERRY       KARAIKAL  2012     6                       2
# 9015      PUDUCHERRY     PUDUCHERRY  2012     7                      14
# 9016      PUDUCHERRY          TOTAL  2012    13                      16
#
#       Dowry Deaths  Assault on women with intent to outrage her modesty  \
# ...

# %%
# REMOVE THE ROWS FROM DATA WHICH ARE SHOWING 'TOTAL NUMBER OF CRIMES IN THE STATE' OR 'TOTAL OF ALL DISTRICS'
df2001_2012 = df2001_2012[df2001_2012['District']!='TOTAL']
df2001_2012 = df2001_2012[df2001_2012['District']!= 'Delhi Ut Total']

# %%
df2001_2012.tail(50)
# Out:
#            State/Ut          District  Year  Rape  Kidnapping & Abduction  \
# 8959    West Bengal            Bkp Cp  2012    36                     201
# 8960    West Bengal           Burdwan  2012    58                      65
# 8961    West Bengal        Coochbehar  2012    92                     169
# 8962    West Bengal  Dakshin Dinajpur  2012    66                     107
# 8963    West Bengal        Darjeeling  2012    10                      39
# 8964    West Bengal           Hooghly  2012    68                     145
# 8965    West Bengal            Howrah  2012    56                     120
# 8966    West Bengal       Howrah City  2012    28                     135
# 8967    West Bengal     Howrah G.R.P.  2012     2                       2
# 8968    West Bengal        Jalpaiguri  2012   163                     279
# 8969    West Bengal          Jhargram  2012    21                      21
# 8970    West Bengal  Kharagpur G.R.P.  2012     2                       4
# ...

# %%
df2013
# Out:
#            State/Ut     District  Year  Rape  Kidnapping & Abduction  \
# 0    Andhra Pradesh     Adilabad  2013    61                      47
# 1    Andhra Pradesh    Anantapur  2013    28                      84
# 2    Andhra Pradesh     Chittoor  2013    31                      27
# 3    Andhra Pradesh     Cuddapah  2013    19                      50
# 4    Andhra Pradesh    Cyberabad  2013   138                     129
# ..              ...          ...   ...   ...                     ...
# 815        Delhi UT          Stf  2013     0                       0
# 816        Delhi UT         West  2013   184                     424
# 818     Lakshadweep  Lakshadweep  2013     2                       0
# 820      Puducherry     Karaikal  2013     6                       2
# 821      Puducherry   Puducherry  2013    11                      23
#
#      Dowry Deaths  Assault on women with intent to outrage her modesty  \
# ...

# %%
df2013 = df2013[df2013['District']!='ZZ TOTAL']

# %%
df2014
# Out:
#            State/Ut          District  Year  Rape  Kidnapping & Abduction  \
# 0    Andhra Pradesh         Anantapur  2014    35                     106
# 1    Andhra Pradesh          Chittoor  2014    32                      34
# 2    Andhra Pradesh          Cuddapah  2014    28                      16
# 3    Andhra Pradesh     East Godavari  2014    85                      25
# 4    Andhra Pradesh  Guntakal Railway  2014     0                       0
# ..              ...               ...   ...   ...                     ...
# 829        Delhi UT         Vigilance  2014     0                       0
# 830        Delhi UT              West  2014   251                     546
# 832     Lakshadweep       Lakshadweep  2014     1                       0
# 834      Puducherry          Karaikal  2014     3                       1
# 835      Puducherry        Puducherry  2014     7                       6
#
#      Dowry Deaths  Assault on women with intent to outrage her modesty  \
# ...

# %%
df2014 = df2014_clean[df2014_clean['District']!= 'Total District(s)']

# %%
df2015
# Out:
#            State/Ut          District    Year   Rape  Kidnapping & Abduction  \
# 0    Andhra Pradesh         Anantapur  2015.0   32.0                    57.0
# 1    Andhra Pradesh          Chittoor  2015.0   31.0                    20.0
# 2    Andhra Pradesh          Cuddapah  2015.0   34.0                    17.0
# 3    Andhra Pradesh     East Godavari  2015.0  104.0                    25.0
# 4    Andhra Pradesh  Guntakal Railway  2015.0    1.0                     0.0
# ..              ...               ...     ...    ...                     ...
# 844        Delhi UT         Vigilance  2015.0    0.0                     0.0
# 845        Delhi UT              West  2015.0  272.0                   525.0
# 847     Lakshadweep       Lakshadweep  2015.0    0.0                     0.0
# 849      Puducherry          Karaikal  2015.0    0.0                     1.0
# 850      Puducherry        Puducherry  2015.0    3.0                    13.0
#
# ...

# %%
# STORING THE INDEX OF ROWS WHICH ARE SHOWING 'TOTAL CRIMES OF ALL DISTRICS'
remove = df2015_clean[df2015_clean['District'] == 'Total District(s)'].index

# %%
df2015 = df2015_clean.drop(remove) # DROP ROWS USING INDEXS

# %% [markdown]
# ### Let's have a look on the datasets

# %%
df2001_2012.head(2)
# Out:
#          State/Ut   District  Year  Rape  Kidnapping & Abduction  \
# 0  Andhra Pradesh   Adilabad  2001    50                      30
# 1  Andhra Pradesh  Anantapur  2001    23                      30
#
#    Dowry Deaths  Assault on women with intent to outrage her modesty  \
# 0            16                                                149
# 1             7                                                118
#
#    Insult to modesty of Women  Cruelty by Husband or his Relatives  \
# 0                          34                                  175
# 1                          24                                  154
#
#    Importation of Girls
# 0                     0
# 1                     0

# %%
df2013.head(2)
# Out:
#          State/Ut   District  Year  Rape  Kidnapping & Abduction  \
# 0  Andhra Pradesh   Adilabad  2013    61                      47
# 1  Andhra Pradesh  Anantapur  2013    28                      84
#
#    Dowry Deaths  Assault on women with intent to outrage her modesty  \
# 0            12                                                197
# 1            23                                                337
#
#    Insult to modesty of Women  Cruelty by Husband or his Relatives  \
# 0                         138                                  464
# 1                          43                                  161
#
#    Importation of Girls
# 0                     0
# 1                     0

# %%
df2014.head(2)
# Out:
#          State/Ut   District  Year  Rape  Kidnapping & Abduction  \
# 0  Andhra Pradesh  Anantapur  2014    35                     106
# 1  Andhra Pradesh   Chittoor  2014    32                      34
#
#    Dowry Deaths  Assault on women with intent to outrage her modesty  \
# 0            25                                                436
# 1            17                                                135
#
#    Insult to modesty of Women  Cruelty by Husband or his Relatives  \
# 0                          26                                  165
# 1                          94                                  278
#
#    Importation of Girls
# 0                     0
# 1                     0

# %%
df2015.head(2)
# Out:
#          State/Ut   District    Year  Rape  Kidnapping & Abduction  \
# 0  Andhra Pradesh  Anantapur  2015.0  32.0                    57.0
# 1  Andhra Pradesh   Chittoor  2015.0  31.0                    20.0
#
#    Dowry Deaths  Assault on women with intent to outrage her modesty  \
# 0          12.0                                              325.0
# 1          10.0                                               94.0
#
#    Insult to modesty of Women  Cruelty by Husband or his Relatives  \
# 0                         8.0                                276.0
# 1                         1.0                                202.0
#
#    Importation of Girls
# 0                   0.0
# 1                   0.0

# %% [markdown]
# #### Here in Dataset 2001-2012 and 2013 'District' is in CAPITAL letters unlike for the dataset 2014 and 2015 so we will make this data in Title type i.e. First letter capital then all small

# %%
df2001_2012['District']=df2001_2012['District'].apply(lambda x :x.title())

# %%
df2001_2012['State/Ut']=df2001_2012['State/Ut'].apply(lambda x :x.title())

# %%
df2001_2012.head(3)
# Out:
#          State/Ut   District  Year  Rape  Kidnapping & Abduction  \
# 0  Andhra Pradesh   Adilabad  2001    50                      30
# 1  Andhra Pradesh  Anantapur  2001    23                      30
# 2  Andhra Pradesh   Chittoor  2001    27                      34
#
#    Dowry Deaths  Assault on women with intent to outrage her modesty  \
# 0            16                                                149
# 1             7                                                118
# 2            14                                                112
#
#    Insult to modesty of Women  Cruelty by Husband or his Relatives  \
# 0                          34                                  175
# 1                          24                                  154
# 2                          83                                  186
#
#    Importation of Girls
# 0                     0
# 1                     0
# 2                     0

# %%
df2013['District']=df2013['District'].apply(lambda x :x.title())

# %%
df2013.head(3)
# Out:
#          State/Ut   District  Year  Rape  Kidnapping & Abduction  \
# 0  Andhra Pradesh   Adilabad  2013    61                      47
# 1  Andhra Pradesh  Anantapur  2013    28                      84
# 2  Andhra Pradesh   Chittoor  2013    31                      27
#
#    Dowry Deaths  Assault on women with intent to outrage her modesty  \
# 0            12                                                197
# 1            23                                                337
# 2            13                                                119
#
#    Insult to modesty of Women  Cruelty by Husband or his Relatives  \
# 0                         138                                  464
# 1                          43                                  161
# 2                          84                                  435
#
#    Importation of Girls
# 0                     0
# 1                     0
# 2                     0

# %% [markdown]
# ## 4. Data Integration: Merging Datasets for Unified Analysis

# %%
crimes_2001_15 = pd.concat([df2001_2012,df2013,df2014,df2015])

# %%
crimes_2001_15.head()
# Out:
#          State/Ut       District    Year  Rape  Kidnapping & Abduction  \
# 0  Andhra Pradesh       Adilabad  2001.0  50.0                    30.0
# 1  Andhra Pradesh      Anantapur  2001.0  23.0                    30.0
# 2  Andhra Pradesh       Chittoor  2001.0  27.0                    34.0
# 3  Andhra Pradesh       Cuddapah  2001.0  20.0                    20.0
# 4  Andhra Pradesh  East Godavari  2001.0  23.0                    26.0
#
#    Dowry Deaths  Assault on women with intent to outrage her modesty  \
# 0          16.0                                              149.0
# 1           7.0                                              118.0
# 2          14.0                                              112.0
# 3          17.0                                              126.0
# 4          12.0                                              109.0
#
#    Insult to modesty of Women  Cruelty by Husband or his Relatives  \
# ...

# %%
crimes_2001_15.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11002 entries, 0 to 850
# Data columns (total 10 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   State/Ut                                             11002 non-null  object
#  1   District                                             11002 non-null  object
#  2   Year                                                 11002 non-null  float64
#  3   Rape                                                 11002 non-null  float64
#  4   Kidnapping & Abduction                               11002 non-null  float64
#  5   Dowry Deaths                                         11002 non-null  float64
#  6   Assault on women with intent to outrage her modesty  11002 non-null  float64
#  7   Insult to modesty of Women                           11002 non-null  float64
# ...

# %% [markdown]
# - All the features and Date are in float type
# - 'Date' column contain the 'Year of crime' so, we will covert it to 'int' type
# - all the other columns are showing number of crimes in each year we can convert them to 'int' type

# %%
x = ['Year','Rape', 'Kidnapping & Abduction', 'Dowry Deaths', 
     'Assault on women with intent to outrage her modesty', 
     'Insult to modesty of Women', 'Cruelty by Husband or his Relatives', 
     'Importation of Girls']

for y in x:
    crimes_2001_15[y] = crimes_2001_15[y].astype('int')

# %%
crimes_2001_15.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11002 entries, 0 to 850
# Data columns (total 10 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   State/Ut                                             11002 non-null  object
#  1   District                                             11002 non-null  object
#  2   Year                                                 11002 non-null  int32
#  3   Rape                                                 11002 non-null  int32
#  4   Kidnapping & Abduction                               11002 non-null  int32
#  5   Dowry Deaths                                         11002 non-null  int32
#  6   Assault on women with intent to outrage her modesty  11002 non-null  int32
#  7   Insult to modesty of Women                           11002 non-null  int32
# ...

# %% [markdown]
# ### Let's check if there are some duplicate or misspelt values in 'State/Ut' Column

# %%
crimes_2001_15['State/Ut'].value_counts().to_frame()
# Out:
#                    count
# State/Ut
# Uttar Pradesh       1094
# Madhya Pradesh       780
# Maharashtra          677
# Bihar                664
# Tamil Nadu           580
# Rajasthan            570
# Odisha               528
# Karnataka            494
# Gujarat              488
# Assam                448
# Andhra Pradesh       431
# Jammu & Kashmir      400
# Punjab               386
# West Bengal          386
# Jharkhand            378
# Chhattisgarh         338
# Haryana              328
# Kerala               283
# Arunachal Pradesh    240
# Himachal Pradesh     209
# Uttarakhand          195
# Delhi                171
# Nagaland             159
# Manipur              143
# Mizoram              125
# Meghalaya            117
# Tripura               82
# Sikkim                61
# Delhi UT              56
# Goa                   32
# A & N Islands         30
# Daman & Diu           30
# Telangana             26
# Puducherry            25
# Chandigarh            15
# ...

# %% [markdown]
# **Here are some misspelt values in 'State/Ut' Column**
# 1. 'A&N Islands'         _instead of_   'A & N Islands'
# 2. 'Delhi UT'            _instead fo_   'Delhi'
# 3. 'D&N Haveli'          _instead of_   'D & N Haveli'

# %%
crimes_2001_15['State/Ut']= crimes_2001_15['State/Ut'].replace('A&N Islands','A & N Islands')
crimes_2001_15['State/Ut']= crimes_2001_15['State/Ut'].replace('Delhi UT','Delhi')
crimes_2001_15['State/Ut']= crimes_2001_15['State/Ut'].replace('D&N Haveli','D & N Haveli')

# %%
crimes_2001_15['State/Ut'].value_counts().to_frame()
# Out:
#                    count
# State/Ut
# Uttar Pradesh       1094
# Madhya Pradesh       780
# Maharashtra          677
# Bihar                664
# Tamil Nadu           580
# Rajasthan            570
# Odisha               528
# Karnataka            494
# Gujarat              488
# Assam                448
# Andhra Pradesh       431
# Jammu & Kashmir      400
# West Bengal          386
# Punjab               386
# Jharkhand            378
# Chhattisgarh         338
# Haryana              328
# Kerala               283
# Arunachal Pradesh    240
# Delhi                227
# Himachal Pradesh     209
# Uttarakhand          195
# Nagaland             159
# Manipur              143
# Mizoram              125
# Meghalaya            117
# Tripura               82
# Sikkim                61
# A & N Islands         33
# Goa                   32
# Daman & Diu           30
# Telangana             26
# Puducherry            25
# Chandigarh            15
# D & N Haveli          15
# ...

# %% [markdown]
# ## 5. Feature Engineering: Creating a Summation Column

# %%
crimes_2001_15['Total Crimes'] = crimes_2001_15[['Rape', 'Kidnapping & Abduction',
       'Dowry Deaths', 'Assault on women with intent to outrage her modesty',
       'Insult to modesty of Women', 'Cruelty by Husband or his Relatives',
       'Importation of Girls']].sum(axis = 1)

# %%
crimes_2001_15.head(2)
# Out:
#          State/Ut   District  Year  Rape  Kidnapping & Abduction  \
# 0  Andhra Pradesh   Adilabad  2001    50                      30
# 1  Andhra Pradesh  Anantapur  2001    23                      30
#
#    Dowry Deaths  Assault on women with intent to outrage her modesty  \
# 0            16                                                149
# 1             7                                                118
#
#    Insult to modesty of Women  Cruelty by Husband or his Relatives  \
# 0                          34                                  175
# 1                          24                                  154
#
#    Importation of Girls  Total Crimes
# 0                     0           454
# 1                     0           356

# %%
crimes_2001_15.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11002 entries, 0 to 850
# Data columns (total 11 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   State/Ut                                             11002 non-null  object
#  1   District                                             11002 non-null  object
#  2   Year                                                 11002 non-null  int32
#  3   Rape                                                 11002 non-null  int32
#  4   Kidnapping & Abduction                               11002 non-null  int32
#  5   Dowry Deaths                                         11002 non-null  int32
#  6   Assault on women with intent to outrage her modesty  11002 non-null  int32
#  7   Insult to modesty of Women                           11002 non-null  int32
# ...

# %% [markdown]
# ### Now Save the complete dataset from 2001 to 2015 in CSV file as 'Crime_Against_Women_2001_to_2015.csv'

# %%
crimes_2001_15.to_csv('Crime_Against_Women_2001_to_2015.csv',index = False)

# %% [markdown]
# # Part - 2 Data Analysis and Visualization

# %% [markdown]
# ## Import all the required Libraries

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load the Dataset we have Prepared in Part - 1 of this Project

# %%
crimes = pd.read_csv('Crime_Against_Women_2001_to_2015.csv')

# %% [markdown]
# ## OVERVIEW OF DATASET

# %%
crimes.head(10)
# Out:
#          State/Ut        District  Year  Rape  Kidnapping & Abduction  \
# 0  Andhra Pradesh        Adilabad  2001    50                      30
# 1  Andhra Pradesh       Anantapur  2001    23                      30
# 2  Andhra Pradesh        Chittoor  2001    27                      34
# 3  Andhra Pradesh        Cuddapah  2001    20                      20
# 4  Andhra Pradesh   East Godavari  2001    23                      26
# 5  Andhra Pradesh   Guntakal Rly.  2001     0                       0
# 6  Andhra Pradesh          Guntur  2001    54                      51
# 7  Andhra Pradesh  Hyderabad City  2001    37                      39
# 8  Andhra Pradesh      Karimnagar  2001    56                      49
# 9  Andhra Pradesh         Khammam  2001    47                      30
#
#    Dowry Deaths  Assault on women with intent to outrage her modesty  \
# 0            16                                                149
# ...

# %%
print(f'There are {len(crimes)} Rows in our Dataset .')
# Out:
# There are 11002 Rows in our Dataset .

# %% [markdown]
# ## 1. Year-Wise Analysis: Trends and Patterns in Crimes Against Women (2001-2015)

# %%
yearly_crimes = crimes.groupby('Year')[['Rape', 'Kidnapping & Abduction',
       'Dowry Deaths', 'Assault on women with intent to outrage her modesty',
       'Insult to modesty of Women', 'Cruelty by Husband or his Relatives',
       'Importation of Girls', 'Total Crimes']].sum()

# %%
yearly_crimes
# Out:
#        Rape  Kidnapping & Abduction  Dowry Deaths  \
# Year
# 2001  16075                   14645          6851
# 2002  16373                   14506          6822
# 2003  15847                   13296          6208
# 2004  18233                   15578          7026
# 2005  18359                   15750          6787
# 2006  19348                   17414          7618
# 2007  20737                   20416          8093
# 2008  21467                   22939          8172
# 2009  21397                   25741          8383
# 2010  22172                   29795          8391
# 2011  24206                   35565          8618
# 2012  24923                   38262          8233
# 2013  33707                   51881          8083
# 2014  36735                   57311          8455
# 2015  34651                   59277          7634
#
#       Assault on women with intent to outrage her modesty  \
# Year
# 2001                                              34124
# ...

# %% [markdown]
# ## Year wise correlation between the Crimes

# %%
plt.figure(figsize=(10, 8),dpi = 100)
sns.heatmap(yearly_crimes.corr(), annot=True, fmt='.2f', cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix of Crimes')
plt.show()

# %% [markdown]
# **key Insights :**
# - Rap case are highly correlated with **kidnappinag & Abduction** , **Assault on women with intent to outrage her modesty** and **Cruelty by husband and Relatives** and Overall Total crimes

# %%
plt.figure(figsize=(10,6),dpi=100)
ax=plt.axes()
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['right'].set_visible(False)

ax.grid(linestyle="--",axis="y",color='gray')

sns.barplot(data=yearly_crimes,x= yearly_crimes.index,y='Total Crimes')

for index,value in enumerate(yearly_crimes['Total Crimes']):
    plt.text(index,value,f'{value}',fontsize = 10,ha = 'center',va = 'bottom')
ax.set_xticklabels(ax.get_xticklabels(),rotation =90)

plt.title("Total number of crimes Each year",fontweight='bold',fontsize=15)

plt.xticks(fontweight='bold')
plt.yticks(fontweight='bold')
plt.xlabel("Year",fontweight='bold')
plt.ylabel("Total Crimes",fontweight='bold')
# Out:
# Text(0, 0.5, 'Total Crimes')

# %% [markdown]
# - Barplot is showing that Number of crimes are increasing over the years and in 2014 it is almost double of 2001
# - In 2015 there is a decline in Number of crimes compared to 2014

# %%
# creat dataset which do not include 'Total Crimes' Column
crimes_data = yearly_crimes[['Rape', 'Kidnapping & Abduction',
       'Dowry Deaths', 'Assault on women with intent to outrage her modesty',
       'Insult to modesty of Women', 'Cruelty by Husband or his Relatives',
       'Importation of Girls']]

# %%
plt.figure(figsize=(10,6),dpi=100)
ax=plt.axes()
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['right'].set_visible(False)

ax.grid(linestyle="--",axis="y",color='gray')

sns.lineplot(data=crimes_data)

plt.title("Crime rate against women in India",fontweight='bold',fontsize=15)

plt.xticks(fontweight='bold')
plt.yticks(fontweight='bold')
plt.xlabel("Year",fontweight='bold')
plt.ylabel("Total Crimes",fontweight='bold')
# Out:
# Text(0, 0.5, 'Total Crimes')

# %% [markdown]
# **From the Above Graph**
# - **Cruelty by husband and his relatives** case are the highest and incresing over the years But it significantly decrese in after 2014
# - **Assault on women with intend to outrage her modesty*** case are second highest between the year 2012 and 2014 there in high increament in these cases
# - **Kidnapping and Abduction** cases are incresing over the years
# - **Rape** cases are incresing over the years But it significantly decrese in after 2014
# - **Insult to Modesty of women,Dowry Death** case are almost contant with a slight variance
# - **Importation of Girls** case are contant over Years

# %%
plt.figure(figsize = (10,6))
crimes_data.plot.bar(stacked = True,figsize = (10,6))

plt.title("Breakdown of Crime Incidents by Category in India",fontweight='bold',fontsize=15)
plt.grid(True,axis = 'y',color = 'grey',linestyle = '--')

# %%
df_melted = pd.melt(crimes_data.reset_index(),id_vars=['Year'],var_name = 'Crime_Type',value_name = 'Total')

# %% [markdown]
# ## Total Crimes from 2001 to 2015

# %%
df_sum_types = pd.DataFrame (df_melted.groupby('Crime_Type')['Total'].sum())

# %%
plt.figure(figsize=(10,6),dpi=100)
ax=plt.axes()
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['right'].set_visible(False)

ax.grid(linestyle="--",axis="y",color='gray')

sns.barplot(data = df_sum_types ,x = df_sum_types.index , y = 'Total')

ax.set_xticklabels(ax.get_xticklabels(),rotation =90)
plt.title("Total number of Crimes from 2001 t0 2014",fontweight='bold',fontsize=16)
plt.xticks(fontweight='bold')
plt.yticks(fontweight='bold')
plt.xlabel("Year",fontweight='bold')
plt.ylabel("Total Crimes",fontweight='bold')
# Out:
# Text(0, 0.5, 'Total Crimes')

# %%
df_sum_types
# Out:
#                                                       Total
# Crime_Type
# Assault on women with intent to outrage her mod...   688551
# Cruelty by Husband or his Relatives                 1230347
# Dowry Deaths                                         115374
# Importation of Girls                                    942
# Insult to modesty of Women                           155063
# Kidnapping & Abduction                               432376
# Rape                                                 344230

# %%
plt.figure(figsize=(10,6),dpi=100)
plt.pie(data = df_sum_types , x = 'Total',labels = df_sum_types.index , autopct = '%1.1f%%')
plt.title("Distribution of Crimes from 2001 to 2014",fontweight='bold',fontsize=16)
plt.show()

# %% [markdown]
# ## State and Union Territory-wise Analysis of Crimes Against Women

# %%
state_crimes = crimes.groupby('State/Ut')[['Rape', 'Kidnapping & Abduction',
       'Dowry Deaths', 'Assault on women with intent to outrage her modesty',
       'Insult to modesty of Women', 'Cruelty by Husband or his Relatives',
       'Importation of Girls', 'Total Crimes']].sum().sort_values(by = 'Total Crimes' , ascending = False)
state_crimes
# Out:
#                     Rape  Kidnapping & Abduction  Dowry Deaths  \
# State/Ut
# Uttar Pradesh      28600                   78088         30963
# Andhra Pradesh     17102                   17936          7096
# West Bengal        25137                   34517          6652
# Rajasthan          26486                   37306          6390
# Madhya Pradesh     49889                   22351         11209
# Maharashtra        28631                   20280          5116
# Assam              21828                   36076          1850
# Kerala             11271                    2418           358
# Odisha             17491                   15381          5747
# Gujarat             6325                   18904           566
# Bihar              16420                   33701         17257
# Karnataka           8117                    9742          3762
# Delhi              12355                   27594          2001
# Tamil Nadu          8751                   16789          2595
# ...

# %% [markdown]
# ## State wise correlation between the crimes

# %%
plt.figure(figsize=(10, 8),dpi = 100)
sns.heatmap(state_crimes.corr(), annot=True, fmt='.2f', cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix of Crimes')
plt.show()

# %% [markdown]
# **Key Insights**
# - Rape ,Assault on women with intent to outrage her modesty are highly correlated.

# %%
plt.figure(figsize=(10,6),dpi=100)
ax=plt.axes()
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['right'].set_visible(False)

ax.grid(linestyle="--",axis="y",color='gray')

sns.barplot(data=state_crimes,x = state_crimes.index,y='Total Crimes')

ax.set_xticklabels(ax.get_xticklabels(),rotation =90)
plt.title("Total number of Crimes in Each State",fontweight='bold',fontsize=16)

plt.xticks(fontweight='bold')
plt.yticks(fontweight='bold')
plt.xlabel("Year",fontweight='bold')
plt.ylabel("Total Crimes",fontweight='bold')
# Out:
# Text(0, 0.5, 'Total Crimes')

# %% [markdown]
# # 10 States with the Highest Crimes are :
#  1. Uttar Pradesh
#  2. Andhra Pradesh
#  3. West Bengol
#  4. Rajasthan
#  5. Madhya Pradesh
#  6. Maharastra
#  7. Assam
#  8. Delhi
#  9. Kerala
#  10. Odisha

# %%
data_10_most = state_crimes[['Rape', 'Kidnapping & Abduction', 'Dowry Deaths',
       'Assault on women with intent to outrage her modesty',
       'Insult to modesty of Women', 'Cruelty by Husband or his Relatives',
       'Importation of Girls']].head(10)
data_10_most = data_10_most.reset_index()
df_most_melted = pd.melt(data_10_most , id_vars= 'State/Ut' , value_vars = data_10_most.columns , var_name= 'Crime_Type', value_name='Total')

# %%
plt.figure(figsize=(14, 8), dpi=100)

# Create the grouped bar plot
sns.barplot(x='State/Ut', y='Total', hue='Crime_Type', data= df_most_melted)

# Customize the plot
plt.xticks(rotation=45, fontweight='bold')
plt.yticks(fontweight='bold')
plt.xlabel("State/Ut", fontweight='bold')
plt.ylabel("Total Crimes", fontweight='bold')
plt.title("Distribution of crimes agaist women in State-Ut with Highest Crimes", fontweight='bold',fontsize=16)
plt.legend(title="Crime Type")
plt.tight_layout()  # Adjust layout to fit labels and legend
plt.grid(True,linestyle = '--',axis = 'y')
# Display the plot
plt.show()

# %% [markdown]
# ## 10 States OR Uts with the least Crimes are
# 1. Meghalaya
# 2. Goa
# 3. Mizoram
# 4. Puducherry
# 5. A & N Islands
# 6. Sikkim
# 7. Nagaland
# 8. D & N Haveli
# 9. Daman & Diu
# 10. Lakshadweep

# %%
data_10_least = state_crimes[['Rape', 'Kidnapping & Abduction', 'Dowry Deaths',
       'Assault on women with intent to outrage her modesty',
       'Insult to modesty of Women', 'Cruelty by Husband or his Relatives',
       'Importation of Girls']].tail(10)
data_10_least = data_10_least.reset_index()
df_least_melted = pd.melt(data_10_least , id_vars= 'State/Ut' , value_vars = data_10_most.columns , var_name= 'Crime_Type', value_name='Total')

# %%
plt.figure(figsize=(14, 8), dpi=100)

# Create the grouped bar plot
sns.barplot(x='State/Ut', y='Total', hue='Crime_Type', data= df_least_melted)

# Customize the plot
plt.xticks(rotation=45, fontweight='bold')
plt.yticks(fontweight='bold')
plt.xlabel("State/Ut", fontweight='bold')
plt.ylabel("Total Crimes", fontweight='bold')
plt.title("Distributioins of crimes agaist women in the State-Ut with Lowest Crimes", fontweight='bold')
plt.legend(title="Crime Type")
plt.tight_layout()  # Adjust layout to fit labels and legend
plt.grid(True,linestyle = '--',axis = 'y')

# Display the plot
plt.show()

# %%
def sort_5(by):
    top_5 = state_crimes.sort_values(by = by,ascending = False).head(5)
    return top_5

# %%
def bar_plot(dataframe,y):
    plt.figure(figsize=(10,6),dpi=100)
    ax=plt.axes()

    ax.grid(linestyle="--",axis="y",color='gray')

    sns.barplot(data = dataframe, x = dataframe.index, y = y)

    # Adding number of crimes on top of each bar
    for index, value in enumerate(dataframe[y]):
        ax.text(index, value, f'{value}', ha='center', va='bottom', fontweight='bold')

    ax.set_xticklabels(ax.get_xticklabels(),rotation =90)
    plt.xticks(fontweight='bold')
    plt.yticks(fontweight='bold')
    plt.xlabel("Sate/Ut",fontweight='bold')
    plt.ylabel(f"Total {y} ",fontweight='bold')

# %%
def pie_chart(dataframe,x):
    plt.figure(figsize = (10,6))
    plt.pie(dataframe[x], labels = dataframe.index , autopct = '%1.1f%%' )
    plt.show()

# %%
def top_5_list(y):
    df=state_crimes.sort_values(by = y , ascending = False)
    first_five = df.head()
    dfr = df.iloc[5:,:]
    # CREATING DATAFRAME SINGLE ROW DATAFRAME OF ALL THE ROWS EXCEPT HEAD()
    dfr = pd.DataFrame(dfr.sum(axis = 0)).transpose()
    
    dfr['Crimes'] ="Others" # reate a columns as ' Crimes'
    
    dfr.set_index('Crimes',inplace = True)
    
    # concat head and others dataframe
    five_n_others = pd.concat([first_five,dfr])
    return five_n_others
top_5_list('Importation of Girls')
# Out:
#                   Rape  Kidnapping & Abduction  Dowry Deaths  \
# Bihar            16420                   33701         17257
# Jharkhand        12466                    8023          4215
# West Bengal      25137                   34517          6652
# Madhya Pradesh   49889                   22351         11209
# Karnataka         8117                    9742          3762
# Others          232201                  324042         72279
#
#                 Assault on women with intent to outrage her modesty  \
# Bihar                                                        8677
# Jharkhand                                                    5793
# West Bengal                                                 38523
# Madhya Pradesh                                             105788
# Karnataka                                                   37987
# Others                                                     491783
#
#                 Insult to modesty of Women  \
# ...

# %%
def top_5(y):
    df=state_crimes.sort_values(by = y , ascending = False)
    first_five = df.head()
    dfr = df.iloc[5:,:]
    # CREATING DATAFRAME SINGLE ROW DATAFRAME OF ALL THE ROWS EXCEPT HEAD()
    dfr = pd.DataFrame(dfr.sum(axis = 0)).transpose()
    
    dfr['Crimes'] ="Others" # create a columns as ' Crimes'
    
    dfr.set_index('Crimes',inplace = True)
    
    # concat head and others dataframe
    five_n_others = pd.concat([first_five,dfr])
    
    


    # Create a figure with 1 row and 2 columns of subplots
    f, ax = plt.subplots(nrows=1, ncols=2, figsize=(12, 5))
    f.patch.set_facecolor('#F2EDD7FF')
    
    # Bar plot
    
    ax[0].bar(first_five.index, first_five[y])
    ax[0].set_title(f'Bar Plot of {y}')
    ax[0].set_xlabel('Categories')
    ax[0].set_ylabel('Values')
    # Adding number of crimes on top of each bar
    for index, value in enumerate(first_five[y]):
         ax[0].text(index, value, f'{value}', ha='center', va='bottom', fontweight='bold')
    
    # Pie chart
    ax[1].pie(five_n_others[y], labels=five_n_others.index, autopct='%1.1f%%')
    ax[1].set_title(f'Pie Chart of {y}')
    
    # Show plot
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Top Five States with Highest number of Rape Crimes

# %%
top_5('Rape')

# %% [markdown]
# # Top Five States with Highest number of 'Kidnapping & Abduction' Crimes

# %%
top_5('Kidnapping & Abduction')

# %% [markdown]
# # Top Five States with Highest number of 'Dowry Deaths' Crimes

# %%
top_5('Dowry Deaths')

# %% [markdown]
# # Top Five States with Highest number of 'Assault on women with intent to outrage her modesty' Crimes

# %%
top_5('Assault on women with intent to outrage her modesty')

# %% [markdown]
# # Top Five States with Highest number of 'Insult to modesty of Women' Crimes

# %%
top_5('Insult to modesty of Women')

# %% [markdown]
# # Top Five States with Highest number of 'Cruelty by Husband or his Relatives' Crimes

# %%
top_5('Cruelty by Husband or his Relatives')

# %% [markdown]
# # Top Five States with Highest number of 'Importation of Girls' Crimes

# %%
top_5('Importation of Girls')

# %% [markdown]
# ## In-Depth Analysis of 3 Highest-Crime States: Trends, Patterns, and Insights

# %%
state_crimes.head(3)
# Out:
#                  Rape  Kidnapping & Abduction  Dowry Deaths  \
# State/Ut
# Uttar Pradesh   28600                   78088         30963
# Andhra Pradesh  17102                   17936          7096
# West Bengal     25137                   34517          6652
#
#                 Assault on women with intent to outrage her modesty  \
# State/Ut
# Uttar Pradesh                                               53491
# Andhra Pradesh                                              68092
# West Bengal                                                 38523
#
#                 Insult to modesty of Women  \
# State/Ut
# Uttar Pradesh                        26576
# Andhra Pradesh                       45682
# West Bengal                           3129
#
#                 Cruelty by Husband or his Relatives  Importation of Girls  \
# State/Ut
# Uttar Pradesh                                105529                     3
# Andhra Pradesh                               146574                    17
# ...

# %% [markdown]
# #                                        Uttar Pradesh

# %%
# create year wise crimes dataframe
up_yearly = crimes[crimes['State/Ut']=='Uttar Pradesh'].groupby('Year')[['Rape', 'Kidnapping & Abduction', 'Dowry Deaths',
       'Assault on women with intent to outrage her modesty',
       'Insult to modesty of Women', 'Cruelty by Husband or his Relatives',
       'Importation of Girls', 'Total Crimes']].sum()

# %%
up_yearly
# Out:
#       Rape  Kidnapping & Abduction  Dowry Deaths  \
# Year
# 2001  1958                    2879          2211
# 2002  1415                    2298          1893
# 2003   911                    1499          1322
# 2004  1397                    2324          1708
# 2005  1217                    2256          1564
# 2006  1314                    2551          1798
# 2007  1648                    3363          2076
# 2008  1871                    4439          2237
# 2009  1759                    5078          2232
# 2010  1563                    5468          2217
# 2011  2042                    7525          2322
# 2012  1963                    7910          2244
# 2013  3050                    9737          2335
# 2014  3467                   10626          2469
# 2015  3025                   10135          2335
#
#       Assault on women with intent to outrage her modesty  \
# Year
# 2001                                               2870
# ...

# %%
up_cat = pd.DataFrame(up_yearly.iloc[:,0:7].sum())
up_cat.columns = ['Total']
up_cat
# Out:
#                                                      Total
# Rape                                                 28600
# Kidnapping & Abduction                               78088
# Dowry Deaths                                         30963
# Assault on women with intent to outrage her mod...   53491
# Insult to modesty of Women                           26576
# Cruelty by Husband or his Relatives                 105529
# Importation of Girls                                     3

# %%
plt.figure(figsize=(10,6),dpi=100)
ax=plt.axes()
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['right'].set_visible(False)

ax.grid(linestyle="--",axis="y",color='gray')

sns.barplot(data = up_yearly , x = up_yearly.index , y = 'Total Crimes')
for index,value in enumerate(up_yearly['Total Crimes']):
    plt.text(index,value,f'{value}',ha = 'center',va='bottom',fontsize = 8)

ax.set_xticklabels(ax.get_xticklabels(),rotation =90)

plt.xticks(fontweight='bold')
plt.yticks(fontweight='bold')
plt.xlabel("Year",fontweight='bold')
plt.ylabel("Total Crimes",fontweight='bold')
# Out:
# Text(0, 0.5, 'Total Crimes')

# %%
plt.figure(figsize=(10,6),dpi=100)
ax=plt.axes()
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['right'].set_visible(False)

ax.grid(linestyle="--",axis="y",color='gray')

sns.lineplot(up_yearly.iloc[:,0:7])


plt.xticks(fontweight='bold')
plt.yticks(fontweight='bold')
plt.xlabel("Year",fontweight='bold')
plt.ylabel("Total Crimes",fontweight='bold')
# Out:
# Text(0, 0.5, 'Total Crimes')

# %%
plt.figure(figsize=(10,6),dpi=100)
ax=plt.axes()
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['right'].set_visible(False)

ax.grid(linestyle="--",axis="y",color='gray')

sns.barplot(data = up_cat,x=up_cat.index,y=up_cat['Total'])
for index,value in enumerate(up_cat['Total']):
    plt.text(index,value,f'{value}',ha = 'center',va='bottom',fontsize = 8)

ax.set_xticklabels(ax.get_xticklabels(),rotation =90)

plt.xticks(fontweight='bold')
plt.yticks(fontweight='bold')
plt.xlabel("Year",fontweight='bold')
plt.ylabel("Total Crimes",fontweight='bold')
# Out:
# Text(0, 0.5, 'Total Crimes')

# %%
plt.figure(figsize=(10,6),dpi=100)
plt.pie(x = up_cat['Total'],labels = up_cat.index,autopct='%1.1f%%')
plt.title("Crime Distribution in Uttar Pradesh",fontweight='bold',fontsize=15)
plt.show()

# %% [markdown]
# # Andhra Pradesh

# %%
# create year wise crimes dataframe
ap_yearly = crimes[crimes['State/Ut']=='Andhra Pradesh'].groupby('Year')[['Rape', 'Kidnapping & Abduction', 'Dowry Deaths',
       'Assault on women with intent to outrage her modesty',
       'Insult to modesty of Women', 'Cruelty by Husband or his Relatives',
       'Importation of Girls', 'Total Crimes']].sum()

# %%
ap_yearly
# Out:
#       Rape  Kidnapping & Abduction  Dowry Deaths  \
# Year
# 2001   871                     765           420
# 2002  1002                     854           449
# 2003   946                     931           466
# 2004  1016                    1030           512
# 2005   935                     995           443
# 2006  1049                    1329           519
# 2007  1070                    1564           613
# 2008  1257                    1396           556
# 2009  1188                    1526           546
# 2010  1362                    1531           588
# 2011  1442                    1612           599
# 2012  1341                    1403           504
# 2013  1635                    1595           492
# 2014   961                     721           215
# 2015  1027                     684           174
#
#       Assault on women with intent to outrage her modesty  \
# Year
# 2001                                               3544
# ...

# %%
ap_cat = pd.DataFrame(ap_yearly.iloc[:,0:7].sum())
ap_cat.columns = ['Total']
ap_cat
# Out:
#                                                      Total
# Rape                                                 17102
# Kidnapping & Abduction                               17936
# Dowry Deaths                                          7096
# Assault on women with intent to outrage her mod...   68092
# Insult to modesty of Women                           45682
# Cruelty by Husband or his Relatives                 146574
# Importation of Girls                                    17

# %%
plt.figure(figsize=(10,6),dpi=100)
ax=plt.axes()
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['right'].set_visible(False)

ax.grid(linestyle="--",axis="y",color='gray')

sns.barplot(data = ap_yearly , x = ap_yearly.index , y = 'Total Crimes')

for index,value in enumerate(ap_yearly['Total Crimes']):
    plt.text(index,value,f'{value}',ha = 'center',va='bottom',fontsize = 8)

ax.set_xticklabels(ax.get_xticklabels(),rotation =90)

plt.xticks(fontweight='bold')
plt.yticks(fontweight='bold')
plt.xlabel("Year",fontweight='bold')
plt.ylabel("Total Crimes",fontweight='bold')
# Out:
# Text(0, 0.5, 'Total Crimes')

# %%
plt.figure(figsize=(10,6),dpi=100)
ax=plt.axes()
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['right'].set_visible(False)

ax.grid(linestyle="--",axis="y",color='gray')

sns.lineplot(ap_yearly.iloc[:,0:7])


plt.xticks(fontweight='bold')
plt.yticks(fontweight='bold')
plt.xlabel("Year",fontweight='bold')
plt.ylabel("Total Crimes",fontweight='bold')
# Out:
# Text(0, 0.5, 'Total Crimes')

# %%
plt.figure(figsize=(10,6),dpi=100)
ax=plt.axes()
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['right'].set_visible(False)

ax.grid(linestyle="--",axis="y",color='gray')

sns.barplot(data = ap_cat,x=ap_cat.index,y=ap_cat['Total'])

for index,value in enumerate(ap_cat['Total']):
    plt.text(index,value,f'{value}',ha = 'center',va='bottom',fontsize = 8)

ax.set_xticklabels(ax.get_xticklabels(),rotation =90)

plt.xticks(fontweight='bold')
plt.yticks(fontweight='bold')
plt.xlabel("Year",fontweight='bold')
plt.ylabel("Total Crimes",fontweight='bold')
# Out:
# Text(0, 0.5, 'Total Crimes')

# %%
plt.figure(figsize=(10,6),dpi=100)
plt.pie(x = ap_cat['Total'],labels = ap_cat.index,autopct='%1.1f%%')
plt.title("Crime Distribution in Andhra Pradesh",fontweight='bold',fontsize=15)
plt.show()

# %% [markdown]
# # West Bengal

# %%
# create year wise crimes dataframe
wb_yearly = crimes[crimes['State/Ut']=='West Bengal'].groupby('Year')[['Rape', 'Kidnapping & Abduction', 'Dowry Deaths',
       'Assault on women with intent to outrage her modesty',
       'Insult to modesty of Women', 'Cruelty by Husband or his Relatives',
       'Importation of Girls', 'Total Crimes']].sum()

# %%
wb_yearly
# Out:
#       Rape  Kidnapping & Abduction  Dowry Deaths  \
# Year
# 2001   709                     695           265
# 2002   759                     694           273
# 2003  1002                     801           329
# 2004  1475                    1018           396
# 2005  1686                    1039           446
# 2006  1731                    1199           445
# 2007  2106                    1590           451
# 2008  2263                    1907           451
# 2009  2336                    2187           506
# 2010  2311                    2764           507
# 2011  2363                    3711           510
# 2012  2046                    4168           593
# 2013  1685                    3830           481
# 2014  1466                    4976           501
# 2015  1199                    3938           498
#
#       Assault on women with intent to outrage her modesty  \
# Year
# 2001                                                954
# ...

# %%
wb_cat = pd.DataFrame(wb_yearly.iloc[:,0:7].sum())
wb_cat.columns = ['Total']
wb_cat
# Out:
#                                                      Total
# Rape                                                 25137
# Kidnapping & Abduction                               34517
# Dowry Deaths                                          6652
# Assault on women with intent to outrage her mod...   38523
# Insult to modesty of Women                            3129
# Cruelty by Husband or his Relatives                 192225
# Importation of Girls                                   131

# %%
plt.figure(figsize=(10,6),dpi=100)
ax=plt.axes()

ax.grid(linestyle="--",axis="y",color='gray')
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['right'].set_visible(False)

sns.barplot(data = wb_yearly , x = wb_yearly.index , y = 'Total Crimes')

for index,value in enumerate(wb_yearly['Total Crimes']):
    plt.text(index,value,f'{value}',ha = 'center',va='bottom',fontsize = 8)

ax.set_xticklabels(ax.get_xticklabels(),rotation =90)
plt.title("Total number of crimes against Women in West Bengal each year",fontsize=15 , color = 'blue')
plt.xticks(fontweight='bold')
plt.yticks(fontweight='bold')
plt.xlabel("Year",fontweight='bold')
plt.ylabel("Total Crimes",fontweight='bold')
# Out:
# Text(0, 0.5, 'Total Crimes')

# %%
plt.figure(figsize=(10,6),dpi=100)
ax=plt.axes()
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.grid(linestyle="--",axis="y",color='gray')

sns.lineplot(wb_yearly.iloc[:,0:7])

plt.title("Crime Rate against Women in West Bengal",fontweight='bold',fontsize=15 , color = 'gray')
plt.xticks(fontweight='bold')
plt.yticks(fontweight='bold')
plt.xlabel("Year",fontweight='bold')
plt.ylabel("Total Crimes",fontweight='bold')
# Out:
# Text(0, 0.5, 'Total Crimes')

# %%
plt.figure(figsize=(10,6),dpi=100)
ax=plt.axes()
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['right'].set_visible(False)

ax.grid(linestyle="--",axis="y",color='gray')

sns.barplot(data = wb_cat,x=wb_cat.index,y=wb_cat['Total'])

for index,value in enumerate(wb_cat['Total']):
    plt.text(index,value,f'{value}',ha = 'center',va='bottom',fontsize = 8)

ax.set_xticklabels(ax.get_xticklabels(),rotation =90)

plt.xticks(fontweight='bold')
plt.yticks(fontweight='bold')
plt.xlabel("Year",fontweight='bold')
plt.ylabel("Total Crimes",fontweight='bold')
# Out:
# Text(0, 0.5, 'Total Crimes')

# %%
plt.figure(figsize=(10,6),dpi=100)
plt.pie(x = wb_cat['Total'],labels = wb_cat.index,autopct='%1.1f%%')
plt.title("Crime Distribution in West Bengal",fontweight='bold',fontsize=15)
plt.show()

# %% [markdown]
# ##  District Wise Crime Analysis

# %% [markdown]
# ### 10 Districts with Highest Crimes

# %%
top_10_districs = crimes.groupby('District').agg({'State/Ut':lambda x : x.mode()[0],'Rape':'sum', 'Kidnapping & Abduction':'sum', 'Dowry Deaths':'sum',
       'Assault on women with intent to outrage her modesty':'sum',
       'Insult to modesty of Women':'sum', 'Cruelty by Husband or his Relatives':'sum',
       'Importation of Girls':'sum','Total Crimes':'sum'}).sort_values(by = 'Total Crimes' , ascending = False ).head(10)
top_10_districs
# Out:
#                          State/Ut  Rape  Kidnapping & Abduction  Dowry Deaths  \
# District
# Murshidabad           West Bengal  4029                    3615           496
# 24 Parganas South     West Bengal  2410                    2517           691
# 24 Parganas North     West Bengal  1998                    2648           718
# Hyderabad City     Andhra Pradesh  1052                    1049           483
# Nadia                 West Bengal  1996                    3440           651
# Cyberabad          Andhra Pradesh  1072                    1133           585
# Karimnagar         Andhra Pradesh  1080                    1446           698
# Mumbai Commr.         Maharashtra  3096                    2339           158
# West Godavari      Andhra Pradesh  1491                     935           295
# Lucknow             Uttar Pradesh   936                    3670           750
#
#                    Assault on women with intent to outrage her modesty  \
# District
# ...

# %%
plt.figure(figsize = (10,5),dpi = 100)
fig = sns.barplot(x = top_10_districs.index , y = 'Total Crimes' , data = top_10_districs)
for container in fig.containers:
    fig.bar_label(container)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ## Key Insights
#
# ### Overall Crime Trends
# * Total crimes increased from 2001 to 2014 but showed a decline in 2015.
# * **Cruelty by Husband and His Relatives** had the highest number of cases, showing an increasing trend but decreased after 2014.
# * **Assault on Women with Intent to Outrage Modesty** showed a significant increase between 2012 and 2014.
# * **Kidnapping and Abduction** and **Rape** cases were on a consistent rise but also decreased after 2014.
# * **Dowry Deaths** and **Insult to Modesty of Women** remained relatively constant with minor variances.
# * **Importation of Girls** cases remained constant over the years.
#
# ### Correlation Insights (From Correlation Matrix)
# * **Rape and Assault on Women with Intent to Outrage Modesty** are highly correlated (**0.899**), indicating that states with high rape cases also tend to have high assault cases.
# * **Kidnapping & Abduction** shows strong correlations with **Rape** (**0.723**) and **Dowry Deaths** (**0.860**), implying these crimes often occur in regions where these crimes are already prevalent.
# * **Cruelty by Husband or His Relatives** is strongly correlated with **Total Crimes** (**0.930**), making it a significant contributor to overall crime rates.
# * **Insult to Modesty of Women** and **Assault on Women with Intent to Outrage Modesty** are moderately correlated (**0.641**), suggesting that these crimes frequently occur together.
# * **Dowry Deaths** and **Kidnapping & Abduction** are also highly correlated (**0.860**), indicating a possible link in regions where these crimes are reported.
# * **Importation of Girls** has a weak correlation with other crimes, indicating that this crime type is relatively isolated from other forms of violence against women.
#
# ### Top 10 States with the Highest Crimes
#   1. Uttar Pradesh
#   2. Andhra Pradesh
#   3. West Bengal
#   4. Rajasthan
#   5. Madhya Pradesh
#   6. Maharashtra
#   7. Assam
#   8. Delhi
#   9. Kerala
#   10. Odisha
#
# ### Top 10 States/UTs with the Least Crimes
#   1. Meghalaya
#   2. Goa
#   3. Mizoram
#   4. Puducherry
#   5. Andaman & Nicobar Islands
#   6. Sikkim
#   7. Nagaland
#   8. Dadra & Nagar Haveli
#   9. Daman & Diu
#   10. Lakshadweep
#
# ### Top 10 Districts with the Highest Crimes
#   1. Murshidabad (West Bengal)
#   2. 24 Parganas South (West Bengal)
#   3. 24 Parganas North (West Bengal)
#   4. Hyderabad City (Andhra Pradesh)
#   5. Nadia (West Bengal)
#   6. Cyberabad (Andhra Pradesh)
#   7. Karimnagar (Andhra Pradesh)
#   8. Mumbai Commr. (Maharashtra)
#   9. West Godavari (Andhra Pradesh)
#   10. Lucknow (Uttar Pradesh)
#
# ---
#
# ## Challenges Faced
#
# * Data inconsistencies across years, such as district name variations, required careful cleaning.
# * Creating visualizations that clearly reflected the scale and severity of crimes across different regions.
#
# ---
#
# ## Conclusion
#
# This project provides a detailed analysis of crimes against women in India from 2001-2015, highlighting significant trends and regions where crimes are most prevalent. These insights can aid policymakers and law enforcement agencies in formulating strategies to address and reduce crime rates, particularly in high-crime regions.

# %% [markdown]
# # ----------------------------------------  Thank You --------------------------------------------------
